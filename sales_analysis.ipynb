# %%
import pandas as pd

# %%
df = pd.read_excel('product_sales_region.xlsx')
#importing the data

# %%
df.head()
# Out:
#         Date   Region Product  Quantity  UnitPrice StoreLocation CustomerType  \
# 0 2023-02-23     East  Laptop        14     163.60       Store B    Wholesale
# 1 2024-12-19    South   Phone         1     544.01       Store A       Retail
# 2 2023-05-10    North    Desk        14     346.18       Store B    Wholesale
# 3 2025-02-26  Central   Chair        18     384.82       Store A    Wholesale
# 4 2023-06-24     East    Desk        18     237.76       Store C       Retail
#
#    Discount Salesperson  TotalPrice PaymentMethod Promotion  Returned  \
# 0      0.00         Eva    2290.400        Online  FREESHIP         0
# 1      0.00       Alice     544.010     Gift Card    SAVE10         0
# 2      0.10       Alice    4361.868        Online  WINTER15         0
# 3      0.15       Frank    5887.746     Gift Card  FREESHIP         0
# 4      0.00      Carlos    4279.680        Online    SAVE10         0
#
# ...

# %%
df.info
#do checks with DISHT with discribe,info,shape,head,tail
# Out:
# <bound method DataFrame.info of            Date   Region  Product  Quantity  UnitPrice StoreLocation  \
# 0    2023-02-23     East   Laptop        14     163.60       Store B
# 1    2024-12-19    South    Phone         1     544.01       Store A
# 2    2023-05-10    North     Desk        14     346.18       Store B
# 3    2025-02-26  Central    Chair        18     384.82       Store A
# 4    2023-06-24     East     Desk        18     237.76       Store C
# ...         ...      ...      ...       ...        ...           ...
# 1495 2025-02-17     West     Desk        13     134.56       Store D
# 1496 2024-01-11    South    Chair        18     209.75       Store C
# 1497 2024-07-27     East     Desk         1     272.50       Store A
# 1498 2024-12-03  Central  Monitor        14     262.67       Store A
# 1499 2025-05-09     West    Chair        13     221.39       Store D
#
#      CustomerType  Discount Salesperson  TotalPrice PaymentMethod Promotion  \
# ...

# %%
df.describe()
# Out:
#                                 Date     Quantity    UnitPrice     Discount  \
# count                           1500  1500.000000  1500.000000  1500.000000
# mean   2024-04-07 21:35:02.400000256    10.410667   298.826947     0.073133
# min              2023-01-01 00:00:00     1.000000     5.520000     0.000000
# 25%              2023-08-20 00:00:00     5.000000   151.020000     0.000000
# 50%              2024-04-08 12:00:00    11.000000   294.740000     0.050000
# 75%              2024-12-07 06:00:00    15.000000   446.702500     0.100000
# max              2025-06-30 00:00:00    20.000000   599.720000     0.150000
# std                              NaN     5.735732   169.100075     0.055979
#
#          TotalPrice     Returned  ShippingCost                      OrderDate  \
# count   1500.000000  1500.000000   1500.000000                           1500
# mean    2919.994952     0.248000     27.507293  2024-04-07 21:35:02.400000256
# ...

# %%
df.describe(include="all")
# Out:
#                                  Date Region Product     Quantity  \
# count                            1500   1500    1500  1500.000000
# unique                            NaN      5       7          NaN
# top                               NaN   East  Tablet          NaN
# freq                              NaN    311     240          NaN
# mean    2024-04-07 21:35:02.400000256    NaN     NaN    10.410667
# min               2023-01-01 00:00:00    NaN     NaN     1.000000
# 25%               2023-08-20 00:00:00    NaN     NaN     5.000000
# 50%               2024-04-08 12:00:00    NaN     NaN    11.000000
# 75%               2024-12-07 06:00:00    NaN     NaN    15.000000
# max               2025-06-30 00:00:00    NaN     NaN    20.000000
# std                               NaN    NaN     NaN     5.735732
#
#           UnitPrice StoreLocation CustomerType     Discount Salesperson  \
# count   1500.000000          1500         1500  1500.000000        1500
# ...

# %%
df.shape
# Out:
# (1500, 19)

# %%
df.tail()
# Out:
#            Date   Region  Product  Quantity  UnitPrice StoreLocation  \
# 1495 2025-02-17     West     Desk        13     134.56       Store D
# 1496 2024-01-11    South    Chair        18     209.75       Store C
# 1497 2024-07-27     East     Desk         1     272.50       Store A
# 1498 2024-12-03  Central  Monitor        14     262.67       Store A
# 1499 2025-05-09     West    Chair        13     221.39       Store D
#
#      CustomerType  Discount Salesperson  TotalPrice PaymentMethod Promotion  \
# 1495       Retail      0.05      Carlos    1661.816   Credit Card  WINTER15
# 1496    Wholesale      0.15       Frank    3209.175    Debit Card  FREESHIP
# 1497    Wholesale      0.00         Eva     272.500     Gift Card  WINTER15
# 1498       Retail      0.05      Carlos    3493.511     Gift Card    SAVE10
# 1499    Wholesale      0.00       Frank    2878.070    Debit Card  FREESHIP
#
#       Returned    OrderID CustomerName  ShippingCost  OrderDate DeliveryDate  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           1500 non-null   datetime64[ns]
#  1   Region         1500 non-null   object
#  2   Product        1500 non-null   object
#  3   Quantity       1500 non-null   int64
#  4   UnitPrice      1500 non-null   float64
#  5   StoreLocation  1500 non-null   object
#  6   CustomerType   1500 non-null   object
#  7   Discount       1500 non-null   float64
#  8   Salesperson    1500 non-null   object
#  9   TotalPrice     1500 non-null   float64
#  10  PaymentMethod  1500 non-null   object
#  11  Promotion      1130 non-null   object
#  12  Returned       1500 non-null   int64
#  13  OrderID        1500 non-null   object
#  14  CustomerName   1500 non-null   object
#  15  ShippingCost   1500 non-null   float64
#  16  OrderDate      1500 non-null   datetime64[ns]
# ...

# %%
df.isnull().sum()
#check for null values
# Out:
# Date               0
# Region             0
# Product            0
# Quantity           0
# UnitPrice          0
# StoreLocation      0
# CustomerType       0
# Discount           0
# Salesperson        0
# TotalPrice         0
# PaymentMethod      0
# Promotion        370
# Returned           0
# OrderID            0
# CustomerName       0
# ShippingCost       0
# OrderDate          0
# DeliveryDate       0
# RegionManager      0
# dtype: int64

# %%
df['Promotion'] = df['Promotion'].fillna('No Promotion')
#code to fill the null values

# %%
df.isnull().sum()
# Out:
# Date             0
# Region           0
# Product          0
# Quantity         0
# UnitPrice        0
# StoreLocation    0
# CustomerType     0
# Discount         0
# Salesperson      0
# TotalPrice       0
# PaymentMethod    0
# Promotion        0
# Returned         0
# OrderID          0
# CustomerName     0
# ShippingCost     0
# OrderDate        0
# DeliveryDate     0
# RegionManager    0
# dtype: int64

# %%
df["Promotion"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
#check for duplicate values
# Out:
# np.int64(0)

# %%
df.dtypes
#to check data types
# Out:
# Date             datetime64[ns]
# Region                   object
# Product                  object
# Quantity                  int64
# UnitPrice               float64
# StoreLocation            object
# CustomerType             object
# Discount                float64
# Salesperson              object
# TotalPrice              float64
# PaymentMethod            object
# Promotion                object
# Returned                  int64
# OrderID                  object
# CustomerName             object
# ShippingCost            float64
# OrderDate        datetime64[ns]
# DeliveryDate     datetime64[ns]
# RegionManager            object
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])
#changing the data type to their appropriate types

# %%
df.dtypes
# Out:
# Date             datetime64[ns]
# Region                   object
# Product                  object
# Quantity                  int64
# UnitPrice               float64
# StoreLocation            object
# CustomerType             object
# Discount                float64
# Salesperson              object
# TotalPrice              float64
# PaymentMethod            object
# Promotion                object
# Returned                  int64
# OrderID                  object
# CustomerName             object
# ShippingCost            float64
# OrderDate        datetime64[ns]
# DeliveryDate     datetime64[ns]
# RegionManager            object
# dtype: object

# %%
df = df.rename(columns={
    'UnitPrice':'unit price',
    'StoreLocation':'store location',
    'CustomerType':'customer type',
    'Salesperson':'sales person',
    'TotalPrice':'total price',
    'PaymentMethod':'payment method',
    'OrderID':'order id',
    'CustomerName':'customer name',
    'ShippingCost':'shipping cost',
    'OrderDate':'order date',
    'DeliveryDate':'delivery date',
    'RegionManager':'region manager'
})
df.columns

#changing the column names to snake casing
# Out:
# Index(['Date', 'Region', 'Product', 'Quantity', 'unit price', 'store location',
#        'customer type', 'Discount', 'sales person', 'total price',
#        'payment method', 'Promotion', 'Returned', 'order id', 'customer name',
#        'shipping cost', 'order date', 'delivery date', 'region manager'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower()
df.columns
# Out:
# Index(['date', 'region', 'product', 'quantity', 'unit price', 'store location',
#        'customer type', 'discount', 'sales person', 'total price',
#        'payment method', 'promotion', 'returned', 'order id', 'customer name',
#        'shipping cost', 'order date', 'delivery date', 'region manager'],
#       dtype='object')

# %%
df[df['total price']<0]
#checking for negative values
# Out:
# Empty DataFrame
# Columns: [date, region, product, quantity, unit price, store location, customer type, discount, sales person, total price, payment method, promotion, returned, order id, customer name, shipping cost, order date, delivery date, region manager]
# Index: []

# %%
df.columns = df.columns.str.replace(' ','_')
df.columns
# Out:
# Index(['date', 'region', 'product', 'quantity', 'unit_price', 'store_location',
#        'customer_type', 'discount', 'sales_person', 'total_price',
#        'payment_method', 'promotion', 'returned', 'order_id', 'customer_name',
#        'shipping_cost', 'order_date', 'delivery_date', 'region_manager'],
#       dtype='object')

# %%
df.head(3)
#checking if everything is ok
# Out:
#         date region product  quantity  unit_price store_location  \
# 0 2023-02-23   East  Laptop        14      163.60        Store B
# 1 2024-12-19  South   Phone         1      544.01        Store A
# 2 2023-05-10  North    Desk        14      346.18        Store B
#
#   customer_type  discount sales_person  total_price payment_method promotion  \
# 0     Wholesale       0.0          Eva     2290.400         Online  FREESHIP
# 1        Retail       0.0        Alice      544.010      Gift Card    SAVE10
# 2     Wholesale       0.1        Alice     4361.868         Online  WINTER15
#
#    returned   order_id customer_name  shipping_cost order_date delivery_date  \
# 0         0  REG100000     Cust 6583          43.34 2023-02-23    2023-02-27
# 1         0  REG100001     Cust 2144           5.30 2024-12-19    2024-12-28
# 2         0  REG100002     Cust 5998          20.46 2023-05-10    2023-05-19
#
#   region_manager
# 0           Eric
# 1         Sophie
# 2           Ryan

# %%
df[(df['discount']<0) | (df['discount']>1)]
#checking if there's any discount values which are not suitable for the table like more that 100% or below 0%
# Out:
# Empty DataFrame
# Columns: [date, region, product, quantity, unit_price, store_location, customer_type, discount, sales_person, total_price, payment_method, promotion, returned, order_id, customer_name, shipping_cost, order_date, delivery_date, region_manager]
# Index: []

# %%
df['discount'].unique()
# Out:
# array([0.  , 0.1 , 0.15, 0.05])

# %%
df['discount'].describe()
# Out:
# count    1500.000000
# mean        0.073133
# std         0.055979
# min         0.000000
# 25%         0.000000
# 50%         0.050000
# 75%         0.100000
# max         0.150000
# Name: discount, dtype: float64

# %%
(df == "").sum()
#checkking if there's any empty rows which are filled with spaces
# Out:
# date              0
# region            0
# product           0
# quantity          0
# unit_price        0
# store_location    0
# customer_type     0
# discount          0
# sales_person      0
# total_price       0
# payment_method    0
# promotion         0
# returned          0
# order_id          0
# customer_name     0
# shipping_cost     0
# order_date        0
# delivery_date     0
# region_manager    0
# dtype: int64

# %%
df.replace(r'^\s*$', pd.NA, regex=True, inplace=True)
#this step clears out the empty rows with spaces and other strings to null values NA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            1500 non-null   datetime64[ns]
#  1   region          1500 non-null   object
#  2   product         1500 non-null   object
#  3   quantity        1500 non-null   int64
#  4   unit_price      1500 non-null   float64
#  5   store_location  1500 non-null   object
#  6   customer_type   1500 non-null   object
#  7   discount        1500 non-null   float64
#  8   sales_person    1500 non-null   object
#  9   total_price     1500 non-null   float64
#  10  payment_method  1500 non-null   object
#  11  promotion       1500 non-null   object
#  12  returned        1500 non-null   int64
#  13  order_id        1500 non-null   object
#  14  customer_name   1500 non-null   object
#  15  shipping_cost   1500 non-null   float64
# ...

# %%
df['region'].unique()
#checking for all the unique values to make sure they're ok
# Out:
# array(['East', 'South', 'North', 'Central', 'West'], dtype=object)

# %%
df['customer_type'].unique()
# Out:
# array(['Wholesale', 'Retail'], dtype=object)

# %%
df['product'].unique()
# Out:
# array(['Laptop', 'Phone', 'Desk', 'Chair', 'Monitor', 'Tablet', 'Printer'],
#       dtype=object)

# %%
df['payment_method'].unique()
# Out:
# array(['Online', 'Gift Card', 'Credit Card', 'Debit Card', 'Cash'],
#       dtype=object)

# %%
df['promotion'].unique()
# Out:
# array(['FREESHIP', 'SAVE10', 'WINTER15', 'No Promotion'], dtype=object)

# %%
df['calculated_price'] = df['quantity'] * df['unit_price'] * ( 1 - df['discount'])
#creating a new column to calculate total price to compare with the existing total_price column to know if its right

# %%
df['calculated_price'].head()
# Out:
# 0    2290.400
# 1     544.010
# 2    4361.868
# 3    5887.746
# 4    4279.680
# Name: calculated_price, dtype: float64

# %%
df['total_price'].head()
# Out:
# 0    2290.400
# 1     544.010
# 2    4361.868
# 3    5887.746
# 4    4279.680
# Name: total_price, dtype: float64

# %%
df['total_price'].unique()
# Out:
# array([2290.4  ,  544.01 , 4361.868, ...,  272.5  , 3493.511, 2878.07 ],
#       shape=(1500,))

# %%
df['calculated_price'].unique()
# Out:
# array([2290.4  ,  544.01 , 4361.868, ...,  272.5  , 3493.511, 2878.07 ],
#       shape=(1500,))

# %%
df[abs(df['calculated_price'] - df['total_price']) > 1]
this compares the total_price and our calculated column to find if there's any difference or wrong with total_price
# Out:
# Empty DataFrame
# Columns: [date, region, product, quantity, unit_price, store_location, customer_type, discount, sales_person, total_price, payment_method, promotion, returned, order_id, customer_name, shipping_cost, order_date, delivery_date, region_manager, calculated_price]
# Index: []

# %%
df.head()
# Out:
#         date   region product  quantity  unit_price store_location  \
# 0 2023-02-23     East  Laptop        14      163.60        Store B
# 1 2024-12-19    South   Phone         1      544.01        Store A
# 2 2023-05-10    North    Desk        14      346.18        Store B
# 3 2025-02-26  Central   Chair        18      384.82        Store A
# 4 2023-06-24     East    Desk        18      237.76        Store C
#
#   customer_type  discount sales_person  total_price payment_method promotion  \
# 0     Wholesale      0.00          Eva     2290.400         Online  FREESHIP
# 1        Retail      0.00        Alice      544.010      Gift Card    SAVE10
# 2     Wholesale      0.10        Alice     4361.868         Online  WINTER15
# 3     Wholesale      0.15        Frank     5887.746      Gift Card  FREESHIP
# 4        Retail      0.00       Carlos     4279.680         Online    SAVE10
#
#    returned   order_id customer_name  shipping_cost order_date delivery_date  \
# ...

# %%
df = df.drop(columns='calculated_price')
#now we can drop the column we created for checking

# %%
df.head()
# Out:
#         date   region product  quantity  unit_price store_location  \
# 0 2023-02-23     East  Laptop        14      163.60        Store B
# 1 2024-12-19    South   Phone         1      544.01        Store A
# 2 2023-05-10    North    Desk        14      346.18        Store B
# 3 2025-02-26  Central   Chair        18      384.82        Store A
# 4 2023-06-24     East    Desk        18      237.76        Store C
#
#   customer_type  discount sales_person  total_price payment_method promotion  \
# 0     Wholesale      0.00          Eva     2290.400         Online  FREESHIP
# 1        Retail      0.00        Alice      544.010      Gift Card    SAVE10
# 2     Wholesale      0.10        Alice     4361.868         Online  WINTER15
# 3     Wholesale      0.15        Frank     5887.746      Gift Card  FREESHIP
# 4        Retail      0.00       Carlos     4279.680         Online    SAVE10
#
#    returned   order_id customer_name  shipping_cost order_date delivery_date  \
# ...

# %%
df['delivery_days'] = (df['delivery_date'] - df['order_date']).dt.days
#this creates a new column with the delivery days from ordering to delivery

# %%
df['delivery_days'].head()
# Out:
# 0    4
# 1    9
# 2    9
# 3    4
# 4    3
# Name: delivery_days, dtype: int64

# %%
df.head()
# Out:
#         date   region product  quantity  unit_price store_location  \
# 0 2023-02-23     East  Laptop        14      163.60        Store B
# 1 2024-12-19    South   Phone         1      544.01        Store A
# 2 2023-05-10    North    Desk        14      346.18        Store B
# 3 2025-02-26  Central   Chair        18      384.82        Store A
# 4 2023-06-24     East    Desk        18      237.76        Store C
#
#   customer_type  discount sales_person  total_price payment_method promotion  \
# 0     Wholesale      0.00          Eva     2290.400         Online  FREESHIP
# 1        Retail      0.00        Alice      544.010      Gift Card    SAVE10
# 2     Wholesale      0.10        Alice     4361.868         Online  WINTER15
# 3     Wholesale      0.15        Frank     5887.746      Gift Card  FREESHIP
# 4        Retail      0.00       Carlos     4279.680         Online    SAVE10
#
#    returned   order_id customer_name  shipping_cost order_date delivery_date  \
# ...

# %%
df[df['delivery_days'] < 1]
#checking if there's any days which is in negative value to find an error in the columns
# Out:
# Empty DataFrame
# Columns: [date, region, product, quantity, unit_price, store_location, customer_type, discount, sales_person, total_price, payment_method, promotion, returned, order_id, customer_name, shipping_cost, order_date, delivery_date, region_manager, delivery_days]
# Index: []

# %%
df.info()
#finally checking for some things to know if everythings okay
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            1500 non-null   datetime64[ns]
#  1   region          1500 non-null   object
#  2   product         1500 non-null   object
#  3   quantity        1500 non-null   int64
#  4   unit_price      1500 non-null   float64
#  5   store_location  1500 non-null   object
#  6   customer_type   1500 non-null   object
#  7   discount        1500 non-null   float64
#  8   sales_person    1500 non-null   object
#  9   total_price     1500 non-null   float64
#  10  payment_method  1500 non-null   object
#  11  promotion       1500 non-null   object
#  12  returned        1500 non-null   int64
#  13  order_id        1500 non-null   object
#  14  customer_name   1500 non-null   object
#  15  shipping_cost   1500 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# date              0
# region            0
# product           0
# quantity          0
# unit_price        0
# store_location    0
# customer_type     0
# discount          0
# sales_person      0
# total_price       0
# payment_method    0
# promotion         0
# returned          0
# order_id          0
# customer_name     0
# shipping_cost     0
# order_date        0
# delivery_date     0
# region_manager    0
# delivery_days     0
# dtype: int64

# %%
df.to_csv('product_sales_region_cleaned.csv', index=False)
